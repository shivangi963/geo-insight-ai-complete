# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from src.llm.property_summarizer import PropertyDescriptionSummarizer
summarizer = PropertyDescriptionSummarizer()

# %%
property_description = """Luxury 3-bedroom penthouse in downtown with panoramic city views.
    Features include hardwood floors, gourmet kitchen with stainless steel appliances,
    master suite with walk-in closet, and private balcony. Building amenities:
    24-hour concierge, fitness center, swimming pool, and secure parking.
    Located steps from restaurants, shopping, and public transportation.
    Perfect for professionals seeking urban luxury living."""
    

    

print("PROPERTY DESCRIPTION SUMMARIZER")
print("-" * 50)
summaries = summarizer.compare_summaries(property_description)
    
print("\n" + "-" * 50)
print("RESULTS SUMMARY:")
for method, summary in summaries.items():
    print(f"{method}: {len(summary)} characters")
# Out:
# PROPERTY DESCRIPTION SUMMARIZER
# --------------------------------------------------
# ================================================================================
# ORIGINAL PROPERTY DESCRIPTION:
# ================================================================================
# Luxury 3-bedroom penthouse in downtown with panoramic city views. Features include hardwood floors, gourmet kitchen with stainless steel appliances, master suite with walk-in closet, and private balcony. Building amenities: 24-hour concierge, fitness center, swimming pool, and secure parking. Located steps from restaurants, shopping, and public transportation. Perfect for professionals seeking urban luxury living.
#
# Original length: 417 characters
# ================================================================================
#
# 1. HUGGING FACE SUMMARY:
# ----------------------------------------
# Device set to use cpu
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 3-bedroom penthouse in downtown with panoramic city views. Features include hardwood floors, gourmet kitchen with stainless steel appliances, master suite with walk-in closet, and private balcony. Located steps from restaurants, shopping, and public transportation.
# Summary length: 265 characters
#
# 2. GEMINI API SUMMARY:
# ----------------------------------------
# Experience urban luxury in this downtown 3-bedroom penthouse, boasting panoramic city views and high-end features like hardwood floors, a gourmet kitchen with stainless steel appliances, a master suite with a walk-in closet, and a private balcony. Residents benefit from building amenities including a 24-hour concierge, fitness center, swimming pool, and secure parking. Strategically located steps from dining, shopping, and public transportation, it's perfect for professionals seeking an upscale, convenient lifestyle.
# Summary length: 522 characters
#
# --------------------------------------------------
# RESULTS SUMMARY:
# Hugging Face: 265 characters
# Gemini: 522 characters
